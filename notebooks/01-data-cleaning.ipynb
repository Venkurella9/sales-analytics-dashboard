# %% [markdown]
# # Data Cleaning Notebook
# This notebook demonstrates the cleaning steps for the generated sales dataset.

# %%
import pandas as pd
df = pd.read_csv('data/sales_data.csv', parse_dates=['order_date'])
df.head()
